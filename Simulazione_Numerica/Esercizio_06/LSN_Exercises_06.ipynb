# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 6</span>

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )
plt.plot(T, e)
plt.title('Ising 1D, internal energy')
plt.xlabel('T')
plt.ylabel('U/N')
plt.show()

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %%
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)
plt.plot(T, heat)
plt.title('Ising 1D, Heat capacity')
plt.xlabel('T')
plt.ylabel('C')
plt.show()

# %% [markdown]
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$

# %%
h=0.02 #external field
b = 1/T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)
plt.plot(T, M)
plt.title('Ising 1D, magnetization M with h = 0.02')
plt.xlabel('T')
plt.ylabel('$M$')
plt.show()

# %% [markdown]
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)
plt.plot(T, X)
plt.title('Ising 1D, Susceptibility')
plt.xlabel('T')
plt.ylabel('$\chi$')
plt.show()

# %% [markdown]
# ### Exercise 06.1
#
# Complete the NSL_simulator code to simulate a 1D Ising model with the Gibbs sampling algorithm (the Metropolis algorithm is already implemented) to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$. Verify the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# - Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties</span> obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with both sampling methods, Metropolis and Gibbs</span>.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.

# %% [markdown]
# Ho aggiunto al mio codice il calcolo delle 4 nuove quantità richieste nella funzione measure() come segue:
#
# ```cpp
# // MAGNETIZATION /////////////////////////////////////////////////////////////
# if (_measure_magnet){
# for (int i=0; i<_npart; i++){
#     _measurement(_index_magnet) += double(_particle(i).getspin());
# }
# _measurement(_index_magnet)/=double(_npart);
# }
# // SPECIFIC HEAT /////////////////////////////////////////////////////////////
# if (_measure_cv and _measure_temp and _measure_tenergy){
# double s_i, s_j;
# for (int i=0; i<_npart; i++){
#     s_i = double(_particle(i).getspin());
#     s_j = double(_particle(this->pbc(i+1)).getspin());
#     cv_temp += - _J * s_i * s_j - 0.5 * _H * (s_i + s_j);
# }
# _measurement(_index_cv) = pow(cv_temp,2);
# }
# // SUSCEPTIBILITY ////////////////////////////////////////////////////////////
# if (_measure_chi and _measure_temp){
# for (int i=0; i<_npart; i++){
#     _measurement(_index_chi) += double(_particle(i).getspin());
# }
# _measurement(_index_chi) = _beta*pow(_measurement(_index_chi),2)/double(_npart);
# }
# ```
#
# Inoltre nel file di input è specificato oltre al $sim\_type$ il valore di $J$ e $H$, ovvero il momento angolare totale e il valore del campo magnetico esterno ($\neq 0$ solo per il calcolo della magnetizzazione).
#
# Nei plot si seguito sono riportate le misure nel corso delle simulazioni delle 4 nuove variabili. Sono mostrate tutte sia per campionamento tramite Metropolis (a sinistra) e tramite Gibbs (a destra), inoltre è sempre presente anche la curva analitica esatta come confronto col modello teorico.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_MTR = pd.read_csv("./NSL_SIMULATOR/OUTPUT/PLOT/total_energy_MTR.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_TE', 'TE_AVE', 'ERROR'])
df_GIBBS = pd.read_csv("./NSL_SIMULATOR/OUTPUT/PLOT/total_energy_GIBBS.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_TE', 'TE_AVE', 'ERROR'])

x = np.arange(0.2, 3.0, 0.05)
x = x[::-1]
beta = 1/x
J = 1.0
Ns = 50
th = np.tanh(J/x)
thN = th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )

def plotting(name, abbreviation, label, number, df, method):
    plt.subplot(1, 2, number)
    plt.plot(x, e, linewidth=2, label='ACTUAL_TE')
    plt.errorbar(x, df[abbreviation + '_AVE'], yerr=df['ERROR'], label=label, marker='o', markersize=4, linewidth=1.5)
    plt.title(method, fontsize=24)
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.xlabel('$T$', fontsize=20)
    plt.ylabel(name, fontsize=20)
    plt.legend(fontsize=16)
    plt.grid(True, alpha=0.5)

plt.figure(figsize=(20, 6))

plotting('Energia Totale', 'TE', 'Energia Totale', 1, df_MTR, 'METROPOLIS')
plotting('Energia Totale', 'TE', 'Energia Totale', 2, df_GIBBS, 'GIBBS')

plt.tight_layout()
plt.show()

# %%
df_MTR = pd.read_csv("/home/davide/Simulazione_Numerica/Esercizio_06/NSL_SIMULATOR/OUTPUT/PLOT/specific_heat_MTR.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_CV', 'CV_AVE', 'ERROR'])
df_GIBBS = pd.read_csv("/home/davide/Simulazione_Numerica/Esercizio_06/NSL_SIMULATOR/OUTPUT/PLOT/specific_heat_GIBBS.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_CV', 'CV_AVE', 'ERROR'])

x = np.arange(0.2, 3.0, 0.05)
x = x[::-1]
beta = 1/x
J = 1.0
Ns = 50
th = np.tanh(J/x)
thN = th**Ns
ch = 1/th

heat = ((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)

def plotting(name, abbreviation, label, number, df, method):
    plt.subplot(1, 2, number)
    plt.plot(x, heat, linewidth=2, label='ACTUAL_HEAT')
    plt.errorbar(x, df[abbreviation + '_AVE'], yerr=df['ERROR'], label=label, marker='o', markersize=4, linewidth=1.5)
    plt.title(method, fontsize=24)
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.xlabel('$T$', fontsize=20)
    plt.ylabel(name, fontsize=20)
    plt.legend(fontsize=16)
    plt.grid(True, alpha=0.5)

plt.figure(figsize=(20, 6))

plotting('Calore Specifico', 'CV', 'Calore Specifico', 1, df_MTR, 'METROPOLIS')
plotting('Calore Specifico', 'CV', 'Calore Specifico', 2, df_GIBBS, 'GIBBS')

plt.tight_layout()
plt.show()

# %%
df_MTR = pd.read_csv("/home/davide/Simulazione_Numerica/Esercizio_06/NSL_SIMULATOR/OUTPUT/PLOT/susceptibility_MTR.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_X', 'X_AVE', 'ERROR'])
df_GIBBS = pd.read_csv("/home/davide/Simulazione_Numerica/Esercizio_06/NSL_SIMULATOR/OUTPUT/PLOT/susceptibility_GIBBS.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_X', 'X_AVE', 'ERROR'])

x = np.arange(0.2, 3.0, 0.05)
x = x[::-1]
beta = 1/x
J = 1.0
Ns = 50
th = np.tanh(J/x)
thN = th**Ns
ch = 1/th

X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)

def plotting(name, abbreviation, label, number, df, method):
    plt.subplot(1, 2, number)
    plt.plot(x, X, linewidth=2, label='ACTUAL_X')
    plt.errorbar(x, df[abbreviation + '_AVE'], yerr=df['ERROR'], label=label, marker='o', markersize=4, linewidth=1.5)
    plt.title(method, fontsize=24)
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.xlabel('$T$', fontsize=20)
    plt.ylabel(name, fontsize=20)
    plt.legend(fontsize=16)
    plt.grid(True, alpha=0.5)

plt.figure(figsize=(20, 6))

plotting('Suscettibilità', 'X', 'Suscettibilità', 1, df_MTR, 'METROPOLIS')
plotting('Suscettibilità', 'X', 'Suscettibilità', 2, df_GIBBS, 'GIBBS')

plt.tight_layout()
plt.show()

# %%
df_MTR = pd.read_csv("/home/davide/Simulazione_Numerica/Esercizio_06/NSL_SIMULATOR/OUTPUT/PLOT/magnetization_MTR.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_M', 'M_AVE', 'ERROR'])
df_GIBBS = pd.read_csv("/home/davide/Simulazione_Numerica/Esercizio_06/NSL_SIMULATOR/OUTPUT/PLOT/magnetization_GIBBS.dat", delim_whitespace=True, skiprows=1, names=['BLOCK', 'ACTUAL_M', 'M_AVE', 'ERROR'])

x = np.arange(0.2, 3.0, 0.05)
x = x[::-1]
h = 0.02
b = 1/x
l1 = np.exp(b*J)*np.cosh(b*h) + np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h) - 2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h) - np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h) - 2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)

def plotting(name, abbreviation, label, number, df, method):
    plt.subplot(1, 2, number)
    plt.plot(x, M, linewidth=2, label='ACTUAL_M')
    plt.errorbar(x, df[abbreviation + '_AVE'], yerr=df['ERROR'], label=label, marker='o', markersize=4, linewidth=1.5)
    plt.title(method, fontsize=24)
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.xlabel('$T$', fontsize=20)
    plt.ylabel(name, fontsize=20)
    plt.legend(fontsize=16)
    plt.grid(True, alpha=0.5)

plt.figure(figsize=(20, 6))

plotting('Magnetizzazione', 'M', 'Magnetizzazione', 1, df_MTR, 'METROPOLIS')
plotting('Magnetizzazione', 'M', 'Magnetizzazione', 2, df_GIBBS, 'GIBBS')

plt.tight_layout()
plt.show()
